# %% [markdown]
# ## Soal 1

# %%
angka = int(input("Masukkan angka: "))
if angka % 2 == 0:
    print(f"{angka} adalah bilangan GENAP!")
else:    print(f"{angka} adalah bilangan GANJIL!")

# %% [markdown]
# ## Soal 2

# %%
massa= float(input("Masukkan massa (kg): "))
tinggi= float(input("Masukkan tinggi (cm): "))
IMT = massa / ((tinggi/100)**2)
status = ""
if IMT < 18.5:
    status = "KURANG"
elif IMT >= 18.5 and IMT < 25.5:
    status = "IDEAL"
elif IMT >= 25.5 and IMT < 30:
    status = "BERLEBIH"
elif IMT >= 30 and IMT < 40:
    status = "SANGAT BERLEBIH"
else:    status = "OBESITAS"
print(f"Massa = {massa} kg dan tinggi = {tinggi/100} m")
print(f"IMT = {IMT:}, BERAT BADAN {status}!")
# Out:
# Massa = 67.0 kg dan tinggi = 1.78 m
# IMT = 21.146319909102385, BERAT BADAN IDEAL!

# %% [markdown]
# ## Soal 3

# %%
jumlah_apel = int(input("Masukkan jumlah apel: "))
jumlah_jeruk = int(input("Masukkan jumlah jeruk: "))
jumlah_anggur = int(input("Masukkan jumlah anggur: "))

harga_apel = 10000
harga_jeruk = 15000
harga_anggur = 20000


total_apel = jumlah_apel * harga_apel
total_jeruk = jumlah_jeruk * harga_jeruk
total_anggur = jumlah_anggur * harga_anggur
total_belanja = total_apel + total_jeruk + total_anggur

detail_belanja = f"""
Detail Belanja
Apel: {jumlah_apel} x {harga_apel} = {total_apel}
Jeruk: {jumlah_jeruk} x {harga_jeruk} = {total_jeruk}
Anggur: {jumlah_anggur} x {harga_anggur} = {total_anggur}

Total : {total_belanja}
"""
print("\n\n"+detail_belanja)

jumlah_uang = int(input("\n\n Masukkan jumlah uang : "))

if jumlah_uang < total_belanja:
    kekurangan = total_belanja - jumlah_uang
    print("Transaksi anda dibatalkan \n uangnya kurang sebesar : ", kekurangan)
elif jumlah_uang > total_belanja:
    kembalian = jumlah_uang - total_belanja
    print("Terimakasih \nUang kembalian anda : ", kembalian)  
else:
    print("Terimakasih")
# Out:
# Detail Belanja
# Apel: 3 x 10000 = 30000
# Jeruk: 2 x 15000 = 30000
# Anggur: 5 x 20000 = 100000
#
# Total : 160000
#
# Terimakasih
